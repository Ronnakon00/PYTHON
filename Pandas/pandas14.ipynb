# %%
import pandas as pd
cols = ['Name','category']
df = pd.read_csv('pandas12.csv',encoding='utf-8',usecols=cols)
df
# Out:
#        Name category
# 0  keyboard       it
# 1     mouse       it
# 2      draw      toy
