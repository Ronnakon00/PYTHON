# %%
import pandas as pd
cols = ['Name','category']
df = pd.read_csv('pandas12.csv',encoding='utf-8',usecols=cols,index_col='Name')
df
# Out:
#          category
# Name
# keyboard       it
# mouse          it
# draw          toy
