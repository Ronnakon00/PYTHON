# %%
import pandas as pd
df = pd.read_excel('Stock.xlsx')
df
# Out:
#                  Name            Category  Price  Amount
# 0               เมาส์  อุปกรณ์คอมพิวเตอร์    900      10
# 1               ปากกา     อุปกรณ์การเรียน    200       5
# 2               โคมไฟ    เครื่องใช้ในบ้าน   1200       7
# 3            ไมโครโฟน     เครื่องใช้ไฟฟ้า    750       1
# 4       เครื่องซักผ้า     เครื่องใช้ไฟฟ้า   3500       0
# 5       เสื้อยืดคอกลม            เสื้อผ้า    500       2
# 6         กางเกงยีนต์            เสื้อผ้า    999       8
# 7       ตุ๊กตาหมีพูห์             ของเล่น    950       5
# 8                โซฟา        เฟอร์นิเจอร์   5000       5
# 9                 จาน         เครื่องครัว    250       4
# 10               ทีวี     เครื่องใช้ไฟฟ้า  15000       7
# 11              ยางลบ     อุปกรณ์การเรียน     20       5
# 12  External HardDisk  อุปกรณ์คอมพิวเตอร์   2500       7
# 13          คีย์บอร์ด  อุปกรณ์คอมพิวเตอร์    850       5
# 14           รถบังคับ             ของเล่น    500       6

# %%
df.sum(axis=0)
# Out:
# Name        เมาส์ปากกาโคมไฟไมโครโฟนเครื่องซักผ้าเสื้อยืดคอ...
# Category    อุปกรณ์คอมพิวเตอร์อุปกรณ์การเรียนเครื่องใช้ในบ...
# Price                                                   33119
# Amount                                                     77
# dtype: object

# %%
df.sum(axis=1) #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.sum(axis=1) #error
#
# File c:\Users\kamok\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)  11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File c:\Users\kamok\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)  12569     **kwargs,
#   12570 ):
# ...
